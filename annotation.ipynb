# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os

# %%
# %matplotlib notebook

# %%
def get_image(file):
    img = cv2.imread(file)
    if img.shape[0] < img.shape[1]:
        img = np.rot90(np.rot90(np.rot90(img)))
        cv2.imwrite("./rtmp.jpg", img)
        img = cv2.imread("./rtmp.jpg")
    return img

# %%
def show(img, change_color = True):
    if change_color:
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    else:
        plt.imshow(img)

# %%
img = get_image("./test_cv.JPG")

# %%
print(img.shape)
# Out:
# (4032, 3024, 3)

# %%
show(img)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLinesP(edges,1,np.pi/180,100,minLineLength,maxLineGap)
print(len(lines))
for x1,y1,x2,y2 in lines[0]:
    cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)
show(img)
# Out:
# 3067
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
img = cv2.imread('dave.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
show(gray, False)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLines(edges,1,np.pi/180,100,minLineLength,maxLineGap)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('houghlines5.jpg',img)
# Out:
# True

# %%
img = cv2.imread('dave.jpg')
average = img.mean(axis=0).mean(axis=0)
print(average)
# Out:
# [173.07176434 183.29799525 190.15914549]

# %%
# frame = get_image('dave.jpg')
# hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

# # define range of blue color in HSV
# lower_blue = np.array([0,0,100])
# upper_blue = np.array([255,200,200])

# #How to define this range for white color


# # Threshold the HSV image to get only blue colors
# mask = cv2.inRange(hsv, lower_blue, upper_blue)
# # Bitwise-AND mask and original image
# res = cv2.bitwise_and(frame,frame, mask= mask)

# show(res, False)

# %%
img = get_image("dave.jpg")
r = image.copy()
# set blue and green channels to 0
r[:, :, 0] = 0
r[:, :, 1] = 0

r = cv2.cvtColor(r, cv2.COLOR_BGR2RGB)

show(r)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
img = r.copy()
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLines(edges,1,np.pi/180,100,minLineLength,maxLineGap)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('houghlines5.jpg',img)
# Out:
# True

# %%
#converted = convert_hls(img)
image = r.copy()
upper = np.uint8([255, 255, 255])
white_mask = cv2.inRange(image, lower, upper)
# yellow color mask
lower = np.uint8([10, 0,   100])
upper = np.uint8([40, 255, 255])
yellow_mask = cv2.inRange(image, lower, upper)
# combine the mask
mask = cv2.bitwise_or(white_mask, yellow_mask)
result = img.copy()

show(mask, False)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
img = cv2.imread('dave.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLines(edges,1,np.pi/180,100,minLineLength,maxLineGap)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('houghlines5.jpg',edges)
# Out:
# True

# %%
cv2.imwrite('houghlines50.jpg',img)
# Out:
# True

# %%
for line in lines:
    for rho,theta in line:
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

# %%
cv2.imwrite('houghlines50.jpg',img)
# Out:
# True

# %%
img = cv2.imread('dave.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLinesP(edges,1,np.pi/180,100,minLineLength,maxLineGap)
# Out:
# True

# %%
for line in lines:
    for x1,y1,x2,y2 in line:
        cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)

cv2.imwrite('houghlines5.jpg', img)
# Out:
# True

# %%
cv2.imwrite('edges.jpg', edges)
# Out:
# True

# %%
img = cv2.imread('dave.jpg')
lower_red = np.array([110,50,50]) 
upper_red = np.array([130,255,255]) 
  
# Here we are defining range of bluecolor in HSV 
# This creates a mask of blue coloured  
# objects found in the frame. 
mask = cv2.inRange(hsv, lower_red, upper_red) 
  
# The bitwise and of the frame and mask is done so  
# that only the blue coloured objects are highlighted  
# and stored in res 
res = cv2.bitwise_and(img,img, mask= mask) 
# cv2.imshow('frame',frame) 
# cv2.imshow('mask',mask) 
# cv2.imshow('res',res) 

# show(res, False)
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
img = get_image("dave.jpg")
img = img[:, 0:1000]
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imwrite('gray.jpg', edges)
v = np.median(gray)

sigma = 0.33
#---- apply automatic Canny edge detection using the computed median----
lower = int(max(0, (1.0 - sigma) * v))
upper = int(min(255, (1.0 + sigma) * v))
edges = cv2.Canny(gray, upper, 1.0)
cv2.imwrite('edges.jpg', edges)
# Out:
# True

# %%
boundaries = [
    ([17, 15, 50], [50, 56, 200]),
    ([86, 31, 4], [220, 88, 50]),
    ([25, 146, 190], [62, 174, 250]),
    ([103, 86, 65], [145, 133, 128])
]

# %%
image = get_image("dave.jpg")
for (lower, upper) in boundaries:
    # create NumPy arrays from the boundaries
    lower = np.array(lower, dtype = "uint8")
    upper = np.array(upper, dtype = "uint8")
 
    # find the colors within the specified boundaries and apply
    # the mask
    mask = cv2.inRange(image, lower, upper)
    output = cv2.bitwise_and(image, image, mask = mask)
    
    cv2.imwrite("hello{}.jpg".format(lower[0]), output)
 
#     # show the images
#     cv2.imshow("images", np.hstack([image, output]))
#     cv2.waitKey(0)

# %%
#--- performs Otsu threshold ---
def threshold(img, st):
    ret, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    cv2.imwrite(os.path.join(os.getcwd(), 'res_' + str(st) + '.jpg'), thresh) 
    return  thresh

# %%
img = get_image("dave.jpg")
# img = cv2.resize(img, (0, 0), fx = 0.5, fy = 0.5)   #--- resized the image because it was to big 
# cv2.imshow('Original', img)

#--- see each of the channels individually ---
# cv2.imshow('b', img[:,:,0])
# cv2.imshow('g', img[:,:,1])
# cv2.imshow('r', img[:,:,2])

m1 = threshold(img[:,:,0], 1)   #--- threshold on blue channel
m2 = threshold(img[:,:,1], 2)   #--- threshold on green channel
m3 = threshold(img[:,:,2], 3)   #--- threshold on red channel

#--- adding up all the results above ---
res = cv2.add(m1, cv2.add(m2, m3))
cv2.imwrite("final.jpg", res)
# Out:
# True

# %%
img = get_image("dave.jpg")
ret, thresh = cv2.threshold(img[:,:,1], 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
ret, thresh2 = cv2.threshold(img[:,:,2], 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
# res = cv2.add(m1, cv2.add(m2, m3))
# gray = cv2.cvtColor(thresh, cv2.COLOR_BGR2GRAY)
thresh = cv2.bitwise_xor(thresh, thresh2)
cv2.imwrite('thresh.jpg',thresh)
edges = cv2.Canny(thresh,50,150,apertureSize = 3)
cv2.imwrite('edges.jpg', edges)
minLineLength = 1000
maxLineGap = 10

# thresh = cv2.bitwise_not(thresh)
lines = cv2.HoughLinesP(thresh,1,np.pi/180,100,minLineLength,maxLineGap)
for line in lines:
    for x1,y1,x2,y2 in line:
        cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)

cv2.imwrite('houghlines5.jpg',img)
# Out:
# True

# %%
mxline = None
best = 0
for line in lines:
    if abs(line[0][1] - line[0][3]) > best:
        mxline = line
        best = abs(line[0][1] - line[0][3])

# %%
print(mxline)
# Out:
# [[ 436 2096  436 1981]]

# %%
img = get_image('dave.jpg')

# cv2.imread('dave.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLinesP(thresh,1,np.pi/180,100,minLineLength,maxLineGap)
for line in lines:
    for x1,y1,x2,y2 in line:
        cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)

cv2.imwrite('houghlines50.jpg',img)
# Out:
# True

# %%
print(len(lines))
# Out:
# 1976

# %%
lines2 = [line for line in lines if abs(line[0][0] - line[0][2]) <= 10]

# %%
img = get_image("dave.jpg")
print(img.shape)
img = img[:, 0:img.shape[1] // 3]

ret, thresh = cv2.threshold(img[:,:,1], 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
ret, thresh2 = cv2.threshold(img[:,:,2], 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
# res = cv2.add(m1, cv2.add(m2, m3))
# gray = cv2.cvtColor(thresh, cv2.COLOR_BGR2GRAY)
thresh = cv2.bitwise_xor(thresh, thresh2)
cv2.imwrite('thresh.jpg',thresh)
edges = cv2.Canny(thresh,50,150,apertureSize = 3)
cv2.imwrite('edges.jpg', edges)
minLineLength = 1000
maxLineGap = 10

lines = cv2.HoughLinesP(thresh,1,np.pi/180,100,minLineLength,maxLineGap)
lines = [line for line in lines if abs(line[0][0] - line[0][2]) <= 10]

for line in lines:
    for x1,y1,x2,y2 in line:
        cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)
cv2.imwrite('houghlines50.jpg',img)
# Out:
# (4032, 3024, 3)
# True

# %%
avgx = np.average([line[0][0] for line in lines])
print(int(avgx))

img = img[:, 0:int(avgx)]

cv2.imwrite('actualfinal.jpg',img)
# Out:
# 444
# True

# %%
# Out:
# [411, 412, 422, 434, 438, 424, 435, 415, 431, 437, 436, 439, 437, 440, 430, 419, 419, 431, 429, 441, 433, 431, 436, 417, 426, 434, 430, 428, 431, 426, 441, 425, 430, 435, 423, 421, 414, 443, 442, 425, 438, 439, 432, 427, 421, 418, 442, 409, 425, 415, 417, 421, 420, 437, 433, 434, 427, 418, 435, 436, 416, 429, 430, 422, 428, 439, 433, 437, 435, 428, 435, 413, 429, 418, 472, 433, 419, 436, 417, 431, 426, 443, 417, 432, 433, 411, 440, 411, 429, 438, 428, 582, 416, 428, 441, 412, 437, 417, 436, 416, 410, 409, 427, 438, 441, 412, 423, 432, 424, 432, 439, 429, 431, 442, 422, 431, 436, 427, 434, 424, 435, 439, 424, 408, 423, 442, 421, 682, 434, 415, 431, 414, 439, 430, 303, 715, 422, 437, 436, 513, 442, 426, 429, 415, 436, 432, 433, 431, 438, 30, 438, 416, 597, 426, 426, 432, 416, 433, 433, 425, 437, 437, 430, 420, 876, 420, 417, 432, 408, 907, 415, 548, 428, 414, 421, 566, 425, 432, 988, 411, 436, 952, 218, 423, 430, 409, 441, 424, 441, 720, 439, 421, 647, 422, 437, 439, 431, 429, 679, 434
# ...
